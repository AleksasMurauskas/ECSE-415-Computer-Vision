# %% [markdown]
# #Assignment 3
# #ECSE 416
# #Aleksas Murauskas, 260718389

# %% [markdown]
# ##Part 1: Data

# %% [markdown]
# ###This dataset is provided along with the assignment. Whereas the complete database contains images from approximately 1000 different subjects, the subset of the dataset that you are provided with contains images from only 52 subjects. The subset is arranged into several folders each containing images of a specific subject in different poses. The number of images per subject varies from 32 to 96. Each image is 768×512 pixels and the files are in PPM format. Convert images to gray-scale and down-sample images by the scale of 4.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
import random

drive.mount('/content/drive')

#Display Image Results Method 
def display_img(image, title_input):
    plt.figure(figsize = (10, 10))
    plt.imshow(image, cmap='gray')
    plt.xticks([]) 
    plt.yticks([]) 
    plt.title(title_input, fontsize = 20)

new_img_size = int((768/4)*(512/4))

file1 =[]
drive_path = '/content/drive/My Drive/ECSE 415/Assignment-3/'
data_path= drive_path+'Color_FERET_Database/'
file1_path=data_path+'00002/'
#Read in all of file 00002

base_img = cv2.imread(file1_path+'00002_930831_fa.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_930831_fb.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_930831_hl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_930831_hr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_930831_pr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_931230_fa.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_931230_fb.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_931230_hl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_931230_pl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_931230_pr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940128_fa.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940128_fb.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940128_hl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940128_hr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940128_pl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940128_pr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940422_fa.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940422_fb.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940422_hl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940422_hr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940422_pl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940422_pr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_fa.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_fb.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_hl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_hr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_pl.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_pr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_ql.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_qr.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_ra.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_rb.ppm')
file1.append(base_img)
base_img = cv2.imread(file1_path+'00002_940928_rc.ppm')
file1.append(base_img)

#Begin File 2
file2 =[]
file2_path=data_path+'00029/'
base_img = cv2.imread(file2_path+'00029_940928_rc.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_fa.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_fb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_hl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_hr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_pl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_pr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_ql.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_qr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_rc.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_rd.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_941031_re.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_fa.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_fb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_hl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_hr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_pl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_pr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_ql.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_qr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_ra.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_rb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960530_rc.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_fa.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_fb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_hl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_hr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_pl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_pr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_ql.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_qr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_ra.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_rb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960620_rc.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_fa.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_fb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_hl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_hr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_pl.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_pr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_ql.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_qr.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_ra.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_rb.ppm')
file2.append(base_img)
base_img = cv2.imread(file2_path+'00029_960627_rc.ppm')
file2.append(base_img)

file3 =[]
file3_path=data_path+'00070/'
base_img = cv2.imread(file3_path+'00070_931230_fa.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_931230_fb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_931230_hr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_931230_pl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_931230_pr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940307_fa.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940307_fb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940307_hl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940307_hr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940307_pl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940307_pr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940422_fa.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940422_fb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940422_hl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940422_hr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940422_pl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940422_pr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_fa.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_fb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_hl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_hr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_pl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_pr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_ql.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_qr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_rc.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_rd.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_940928_re.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_fa.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_fb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_hl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_hr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_pl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_pr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_ql.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_qr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_rc.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_rd.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941031_re.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_fa.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_fb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_hl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_hr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_pl.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_pr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_ql.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_qr.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_ra.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_rb.ppm')
file3.append(base_img)
base_img = cv2.imread(file3_path+'00070_941121_rc.ppm')
file3.append(base_img)
#Gather File4 images
file4 =[]
file4_path=data_path+'00093/'
base_img = cv2.imread(file4_path+'00093_931230_fa.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_931230_fb.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_931230_hr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_931230_pl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_931230_pr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_940128_fa.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_940128_fb.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_940128_hl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_940128_hr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_940128_pl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_940128_pr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_fa.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_fb.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_hl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_hr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_pl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_pr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_ql.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_qr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_rc.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_rd.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941031_re.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_fa.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_fb.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_hl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_hr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_pl.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_pr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_ql.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_qr.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_rc.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_rd.ppm')
file4.append(base_img)
base_img = cv2.imread(file4_path+'00093_941121_re.ppm')
file4.append(base_img)

subject_names =["Subject: 2","Subject: 29","Subject: 70","Subject: 93"]
old_y =512
old_x = 768
new_w = int(old_y/4)
new_h = int(old_x/4)
#Store images from each file
file1_set = []
file2_set = []
file3_set=[]
file4_set=[]


for img in file1:
  #Set to Gray
  working_img =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #Adjust Size 
  height,width =working_img.shape
  #Down sample the size by 4
  dim = (new_w,new_h)
  resized_img = cv2.resize(working_img, dim, interpolation =cv2.INTER_AREA)
  file1_set.append(resized_img)
print("There are :" +str(len(file1_set))+" images of subject 2")
for img in file2:
  #Set to Gray
  working_img =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #Adjust Size 
  height,width =working_img.shape
  #Down sample the size by 4
  dim = (new_w,new_h)
  resized_img = cv2.resize(working_img, dim, interpolation =cv2.INTER_AREA)
  file2_set.append(resized_img)
print("There are :" +str(len(file2_set))+" images of subject 29")
for img in file3:
  #Set to Gray
  working_img =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #Adjust Size 
  height,width =working_img.shape
  #Down sample the size by 4
  dim = (new_w,new_h)
  resized_img = cv2.resize(working_img, dim, interpolation =cv2.INTER_AREA)
  file3_set.append(resized_img)
print("There are :" +str(len(file3_set))+" images of subject 70")
for img in file4:
  #Set to Gray
  working_img =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #Adjust Size 
  height,width =working_img.shape
  #Down sample the size by 4
  dim = (new_w,new_h)
  resized_img = cv2.resize(working_img, dim, interpolation =cv2.INTER_AREA)
  file4_set.append(resized_img)
print("There are :" +str(len(file4_set))+" images of subject 93")
#Helper methods to ensure it is visible. 
#display_img(file1_set[-1],"Test image")
#display_img(file1[-1],"Test image")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# There are :33 images of subject 2
# There are :45 images of subject 29
# There are :50 images of subject 70
# There are :33 images of subject 93

# %% [markdown]
# ###You now need to prepare your dataset for a face recognition and detection system. Randomly separate the images into training and test sets as described below. A new random selection should be made by your program every time the system is retrained
#
# ###Train set: For each subject, randomly select 80% of the total images given for that subject. This will be used as the training set.

# %%
#Create file 1Training Set
file1_train = file1_set.copy()
f1_len = len(file1_train) 
test_set_size= f1_len*.20  #Find 20% for the test set
file1_test = [] #Will hold the images for the test set. 
counter=0
while(counter<test_set_size): #create a random test set
  active_len = len(file1_train) #Find current length
  chosen_ind = random.randint(0,active_len-1) #Select 1 to remove
  random_img = file1_train.pop(chosen_ind) #Pop the image from Train
  file1_test.append(random_img) #Append image to test
  counter=counter+1 #iterate

#Create file 2 Training Set
file2_train = file2_set.copy()
f2_len = len(file2_train) 
test_set_size= f2_len*.20  #Find 20% for the test set
file2_test = [] #Will hold the images for the test set. 
counter=0
while(counter<test_set_size): #create a random test set
  active_len = len(file2_train) #Find current length
  chosen_ind = random.randint(0,active_len-1) #Select 1 to remove
  random_img = file2_train.pop(chosen_ind) #Pop the image from Train
  file2_test.append(random_img) #Append image to test
  counter=counter+1 #iterate

#Create file 3 Training Set
file3_train = file3_set.copy()
f3_len = len(file3_train) 
test_set_size= f3_len*.20  #Find 20% for the test set
file3_test = [] #Will hold the images for the test set. 
counter=0
while(counter<test_set_size): #create a random test set
  active_len = len(file3_train) #Find current length
  chosen_ind = random.randint(0,active_len-1) #Select 1 to remove
  random_img = file3_train.pop(chosen_ind) #Pop the image from Train
  file3_test.append(random_img) #Append image to test
  counter=counter+1 #iterate

#Create file 4 Training Set
file4_train = file4_set.copy()
f4_len = len(file4_train) 
test_set_size= f4_len*.20  #Find 20% for the test set
file4_test = [] #Will hold the images for the test set. 
counter=0
while(counter<test_set_size): #create a random test set
  active_len = len(file4_train) #Find current length
  chosen_ind = random.randint(0,active_len-1) #Select 1 to remove
  random_img = file4_train.pop(chosen_ind) #Pop the image from Train
  file4_test.append(random_img) #Append image to test
  counter=counter+1 #iterate

# %% [markdown]
# ###Test set: All the remaining images from the given subset which are not used in the training set will be used as test images.

# %%
#Test set also created in previous code 
#Print statements to display the size of the input, train, and test sets. 
print("Original Subject 2 set size is "+str(len(file1_set)))
print("Size of Subject 2 train set is "+str(len(file1_train)))
print("Size of Subject 2 test set is "+ str(len(file1_test)))
print("Original Subject 29 set size is "+str(len(file2_set)))
print("Size of Subject 29 train set is "+str(len(file2_train)))
print("Size of Subject 29 test set is "+ str(len(file2_test)))
print("Original Subject 70 set size is "+str(len(file3_set)))
print("Size of Subject 70 train set is "+str(len(file3_train)))
print("Size of Subject 70 test set is "+ str(len(file3_test)))
print("Original Subject 93 set size is "+str(len(file4_set)))
print("Size of Subject 93 train set is "+str(len(file4_train)))
print("Size of Subject 93 test set is "+ str(len(file4_test)))
# Out:
# Original Subject 2 set size is 33
# Size of Subject 2 train set is 26
# Size of Subject 2 test set is 7
# Original Subject 29 set size is 45
# Size of Subject 29 train set is 36
# Size of Subject 29 test set is 9
# Original Subject 70 set size is 50
# Size of Subject 70 train set is 40
# Size of Subject 70 test set is 10
# Original Subject 93 set size is 33
# Size of Subject 93 train set is 26
# Size of Subject 93 test set is 7

# %% [markdown]
# ###Display total 10 random images. Plot histogram of the frequency of each image class (in this case the subject) distribution.

# %%
complete_train =[]
print("Below is the indexing of the training set")
for img in file1_train:
  complete_train.append(img)
last_in = len(complete_train)-1
print("images up to index "+ str(last_in)+" are of subject 2")
for img in file2_train:
  complete_train.append(img) 
print("images between index "+ str(last_in+1)+" and "+str(len(complete_train)-1) +" are of subject 29")
last_in = len(complete_train)-1
for img in file3_train:
  complete_train.append(img) 
print("images between index "+ str(last_in+1)+" and "+str(len(complete_train)-1) +" are of subject 70")
last_in = len(complete_train)-1
for img in file4_train:
  complete_train.append(img) 
print("images between index "+ str(last_in+1)+" and "+str(len(complete_train)-1) +" are of subject 93")

#Combine all the testing sets into one set
print("Below is the indexing of the testing set")
complete_test =[]
for img in file1_test:
  complete_test.append(img)
last_in = len(complete_test)-1
print("images up to index "+ str(last_in)+" are of subject 2")
for img in file2_test:
  complete_test.append(img)
print("images between index "+ str(last_in+1)+" and "+str(len(complete_test)-1) +" are of subject 29")
last_in = len(complete_train)-1
for img in file3_test:
  complete_test.append(img)
print("images between index "+ str(last_in+1)+" and "+str(len(complete_test)-1) +" are of subject 70")
last_in = len(complete_train)-1
for img in file4_test:
  complete_test.append(img)
print("images between index "+ str(last_in+1)+" and "+str(len(complete_test)-1) +" are of subject 93")


#Create Histogram of data
height = [26.0/128,36/128.0,40/128.0,26/128.0]
x=np.arange(4)
plt.bar(x,height)
plt.xticks(x,['Subject 2','Subject 29','Subject 70','Subject 93'])
plt.title("Histogram")
plt.xlabel("Subject")
plt.ylabel("Fraction of Data")
plt.show()


#Display 10 Random Images 
for x in range(10):
  tit = "Random Image: " +str(x+1)
  ind = random.randint(0,128)
  display_img(complete_train[ind],tit)
# Out:
# Below is the indexing of the training set
# images up to index 25 are of subject 2
# images between index 26 and 61 are of subject 29
# images between index 62 and 101 are of subject 70
# images between index 102 and 127 are of subject 93
# Below is the indexing of the testing set
# images up to index 6 are of subject 2
# images between index 7 and 15 are of subject 29
# images between index 128 and 25 are of subject 70
# images between index 128 and 32 are of subject 93

# %% [markdown]
# ##Part 2 Eigenface Representation

# %% [markdown]
# ###You are now ready to create an eigenface representation for your training dataset through PCA. Please note that you are not allowed to use the in-built PCA function in OpenCV/Scikit-Learn. You should implement the efficient Snapshot method for PCA (covered in class, Lecture 9, Slide 55) from scratch using numpy.

# %%
#List to hold Image vectors 
train_vector =[]
test_vector=[]
tot_data =[]
img_size = new_h*new_w

tot_data = complete_test+complete_train

#Create a new lest  to act as the vector 
for active in complete_train:
  f1_face=active.reshape(img_size,)
  train_vector.append(f1_face)
active_vector =np.asarray(train_vector)
active_vector= active_vector.transpose()

#Creation of a test vector
for active in complete_test: 
  face = active.reshape(img_size,)
  test_vector.append(face)

test_vector = np.asarray(test_vector)
test_vector= test_vector.transpose()

#print("Vector shape check : "+str(active_vector.shape))
#Find Mean to Normalize Vector
#FInd the Mean along the axis
mean_vector = active_vector.mean(axis=1)
#Stretch the mean to the shape of the original vector. 
mean_vector_reshaped = mean_vector.reshape(active_vector.shape[0],1)
#Normalize the vector by subtracting the found mean 
normalized_vector = active_vector -mean_vector_reshaped
#Find Covariance
trans_vector = np.transpose(normalized_vector)
cov = np.cov(trans_vector)
#Now to find EigenVectors 
eig_vals, eig_vectors = np.linalg.eig(cov)
#print(eig_vals)
#print(eig_vectors.shape)

#Repeat for the test cases
mean_test_vector = test_vector.mean(axis=1)
mean_test_vector_re =  mean_test_vector.reshape(test_vector.shape[0],1)
test_norm_vector = test_vector - mean_test_vector_re
test_trans_vector = np.transpose(test_norm_vector)
cov2 = np.cov(test_trans_vector)
_, test_eig = np.linalg.eig(cov2)
#print(test_eig.shape)

#Testing with eigenface over whole dataset
data_set=[]
for item in tot_data:
  f1_face=item.reshape(img_size,)
  data_set.append(f1_face)
data_vector = np.asarray(data_set)
data_vector= data_vector.transpose()
tot_mean = data_vector.mean(axis=1)
tot_mean_re = tot_mean.reshape(data_vector.shape[0],1)
norm_set = data_vector- tot_mean_re
trans_data = np.transpose(norm_set)
cov3 = np.cov(trans_data)
_,total_eig_vector  = np.linalg.eig(cov3)

# %% [markdown]
# ###Plot the fraction of total variance against the number of eigenvectors

# %%
def graph_plot(title,x_lab,y_lab, max_x,data): #Method to display the eigen values
  plt.figure(figsize=(10,5))
  plt.title(title)
  plt.xlabel(x_lab)
  plt.ylabel(y_lab)
  x_axis = range(1,max_x)
  plt.plot(x_axis,data)
  plt.grid(True)
  plt.show()

#num_x, num_y= eig_vectors.shape()
#temp = sorted(zip(eig_vals,eig_vectors), reverse = True)
sorted_eig_vectors =[eig_vectors for _,eig_vectors in sorted(zip(eig_vals,eig_vectors), reverse = True)]
sorted_eig_vectors = np.array(sorted_eig_vectors)
#Sort Eigenvalues 
sorted_eig_vals =sorted(eig_vals, reverse=True)
#Find total variance 
var_plot =[]
for x in range(len(eig_vals)):
  variance=0
  for y in range(x+1):
    variance+= eig_vals[y]
  var_plot.append(variance)

total_variance = var_plot[-1]
sum_var = sum(eig_vals)
normalized_eig_vals= eig_vals/sum_var
fraction_var_plot =var_plot/total_variance

graph_plot("Fraction of Total Variance vs. Eigenvector Number","Eigenvector","Variance",len(eig_vals)+1,fraction_var_plot)

# %% [markdown]
# ###Plot the normalized variance (eigenvalues) against the eigenvector index used for computation.

# %%
graph_plot("Eigenvalue vs. Eigenvector Number","Eigenvector","Eigenvalue",len(normalized_eig_vals)+1,normalized_eig_vals)

# %% [markdown]
# ###Do you need all the vectors to represent the data? Discuss

# %% [markdown]
# As shown by the dimininishing variance as the index of eigenvectors increases: The marginal value in the addition of more training image data is diminishing as well. As shown in the Eigenvalue graph, beyond 10 images, the marginal variance is already less than 0.025. The trend is similar to the equation y=x^(0.5)

# %% [markdown]
# ### Display the first 5 eigenfaces

# %%
top_five_vectors = sorted_eig_vectors[:5,:] #Grabs first 5 eigen vectors
#print("eigen vector shape"+str(sorted_eig_vectors.shape))
#print("Best vector shape"+str(top_five_vectors.shape))
#Transpose vector to face
temp = np.transpose(normalized_vector)
best_eig_faces = top_five_vectors.dot(temp)
#print("Face shape"+str(best_eig_faces.shape))
temp2 =np.transpose(best_eig_faces)
weight = temp.dot(temp2)

face_display =[]
#Creat display list of eigenfaces
for x in range(5):
  active_img = best_eig_faces[x]
  active_img = active_img.reshape(new_h,new_w)
  face_display.append(active_img)
#Display best faces
for x in range(5):
  tit = "Best Face Number: " +str(x+1)
  display_img(face_display[x],tit)

# %% [markdown]
# ##Part 3 Classification

# %% [markdown]
# ###For every testing image, find the nearest neighbour (L2 distance), and check whether both images belong to the same person. To estimate the accuracy of this approach, determine what fraction of your test images has a neighbour that is actually of the same person? Compute the accuracy both in the original high dimensional pixel space and then in the eigenspace, and compare the accuracy values. Would you expect there to be a significant difference?

# %%
#Array used to compare the members 
known_test_subjects =[]
known_vector_subjects = []

for a in range(7):
  known_test_subjects.append(2)
for a in range(9):
  known_test_subjects.append(29)
for a in range(10):
  known_test_subjects.append(70)
for a in range(7):
  known_test_subjects.append(93)
#Set known order of active vector. 
for a in range(26):
  known_vector_subjects.append(2)
for a in range(36):
  known_vector_subjects.append(29)
for a in range(40):
  known_vector_subjects.append(70)
for a in range(26):
  known_vector_subjects.append(93)

total_known_subjects = known_test_subjects+known_vector_subjects


def calculateAccuracy(train_subjects, test_subjects):
  #Set known order to detect if correct subject identified. 
  match_count=0
  for a in range(len(test_subjects)): #Iterate through test subjects
    found_dist = float('inf') #Set infinite distance
    for b in range(len(train_subjects)):
      dist_L2 = np.linalg.norm(test_subjects[a]- train_subjects[b],ord=2) #Find norm
      if dist_L2< found_dist: #Record lowest norm
        found_dist =dist_L2
        found_index=b
    if(known_test_subjects[a]==known_vector_subjects[found_index]): #
      match_count=match_count+1
  acc =match_count*100/len(test_subjects)
  return acc

def calculateEigAccuracy(total_data):
  match_count=0
  for a in range(33): #Iterate through test subjects
    found_dist = float('inf') #set infinite distance 
    for b in range(33,len(total_data)): #Iterate through train subjects
      dist_L2 = np.linalg.norm(total_data[a]-total_data[b],ord=2) #The Norm is the distance
      if dist_L2< found_dist:
        found_dist =dist_L2
        found_index=b
    if(total_known_subjects[a]==total_known_subjects[found_index]):
      match_count=match_count+1
  acc =match_count*100/33
  return acc


final_train_vector = np.transpose(active_vector)
final_test_vector = np.transpose(test_vector)
final_eig_vector = np.transpose(total_eig_vector)
eig_face = eig_vectors.dot(np.transpose(normalized_vector))
#test_eig_face = test_eig.dot(np.transpose(normalized_vector))

stan_acc = calculateAccuracy(final_train_vector,final_test_vector)
test_eig = calculateAccuracy(eig_face,final_test_vector)
eig_acc = calculateEigAccuracy(final_eig_vector)

print("Standard High dimension Prediction percentage found was: "+str(int(stan_acc))+"%")
#print("Eigen Face Prediction percentage found was: "+str(int(test_eig))+"%")
print("Eigenvector Prediction percentage found was: "+ str(int(eig_acc))+"%")
# Out:
# Standard High dimension Prediction percentage found was: 51%
# Eigenvector Prediction percentage found was: 27%

# %% [markdown]
# Over the course of testing, High dimension prediction
# percentage hovered between 45% and 70%, while the Eigenvector prediction percentage hovered between 20% and 40%. The eigenvector prediction I was able to find was roughly half that of the standard high quality image prediction. The Eigenspace method shoudld be running at at least par or slighltly better than the higher dimension. Either there is an issue with my method or the data set has too much or too little variance to properly detect in eigenspace.

# %% [markdown]
# ###You will now use a linear SVM classifier in the eigenspace. Use the training dataset to fit the classifier and the testing dataset to test the classifier. Compare the accuracy of this classifier with the nearest neighbour classifier used previously

# %%
from sklearn import svm
from sklearn import datasets

clf = svm.LinearSVC(C=0.001)
#Linear SVM on simple data
clf.fit(final_train_vector,known_vector_subjects)
predictions = clf.predict(final_test_vector)
count=0
for a in range(len(predictions)):
  if(predictions[a]==known_test_subjects[a]):
    count=count+1 #Increment for each correct identification
high_acc = 100*count/len(predictions) #Find the accuracy

print("Accuracy of SVM on the Data is "+ str(int(high_acc))+"%")

dlf = svm.LinearSVC(C=0.001)
dlf.fit(total_eig_vector[33:],known_vector_subjects)
predictions = dlf.predict(total_eig_vector[:33])
count=0
for a in range(len(predictions)): #Check predictions 
  if(predictions[a]==total_known_subjects[a]):
    count=count+1
eig_acc2 = 100*count/len(predictions) #Find the accuracy
print("Accuracy of SVM on the Eigen Data is "+ str(int(eig_acc2))+"%")
# Out:
# Accuracy of SVM on the Data is 87%
# Accuracy of SVM on the Eigen Data is 30%
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# The SVM was signifigantly more accurate on the High , as it's accuracy hovered around 66% and 94% when run on different data sets. The SVM perfromed a consistent 20% better than the indentifier I created on High dimensional data. On eigenspace the accuracy was roughly equivalent to the indentifier I created. The result of SVM on the eigen data seems to display a comprable accuracy with my initial L2 distance detector. This seems to imply there is an issue with my implementation of eigen vectors. If i can find the cause of the issue I will note it here.

# %% [markdown]
# ##Part 4 Face Detection

# %% [markdown]
# ###You will now detect all the faces in the given group image (Schitts Creek group.jpg) using PCA. Use a sliding window to detect the faces. Set a threshold on the distance in eigenspace between the window contents and your training data (Referto slide 63 of Lecture 9). Try different values of thresholds and use the one which gives you good results. Display your image with bounding boxes around the detected faces for the best threshold. (ex. Figure 1)

# %%
drive_path = '/content/drive/My Drive/ECSE 415/Assignment-3/'
img = cv2.imread(drive_path+'Schitts_Creek_group.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
group_display = img_gray.copy()
threshold =83000000

loc = []
def windows(image, stride_x, stride_y,win_size):
  panes = []
  for y in range(0, image.shape[0]-stride_y,stride_y):
    for x in range(0,image.shape[1]-stride_x,stride_x):
      panes.append(image[y:y+win_size[0], x:x+win_size[1]])
      coordinate = [y,x,y+win_size[0],x+win_size[1]]
      loc.append(coordinate)
  return panes

def find_min_distance(group_display,panes,win_size,mean,eig_face, weight):
  active_img = group_display.copy()
  panes= np.asarray(panes)
  count =0
  for pane in panes:
    curr_pane=cv2.resize(pane,(192,128), interpolation=cv2.INTER_AREA)
    past_pane = curr_pane
    curr_pane = curr_pane.reshape(192*128,1)
    norm_face = curr_pane-mean
    tst = np.transpose(norm_face).dot(np.transpose(eig_face))
    norm=np.linalg.norm(tst,ord=2,axis=1)
    dist=min(norm)
    if(dist < threshold):
      print(dist)
      active_img =cv2.rectangle(active_img, (loc[count][1],loc[count][0]), (loc[count][3],loc[count][2]), (255,0,0), 2)
    count=count+1
  return active_img

w = np.transpose(normalized_vector).dot(np.transpose(eig_face))

win_Dim =(125,100)
win_ret = windows(group_display, 100,125, win_Dim)
disp_img=find_min_distance(group_display,win_ret, win_Dim, mean_vector,eig_face,w)
display_img(disp_img,"Final Image")
# Out:
# 61781716.72389499
# 59108235.086543866
# 76241959.23490219
# 38357364.009948745
# 31376790.925203405
# 41056013.004232235
# 25229929.83270685

# %% [markdown]
# ###Use an existing implementation of the Viola-Jones face detector, and compare the results with your detector. Comparisons should be made in terms ofthe number of true positives, false positives and false negatives (See Appendix).Display the image with bounding boxes around the detected faces. Under whatconditions would you expect the Viola-Jones detector to work when PCA does not?

# %%
#Below is code from the tutorial
drive_path = '/content/drive/My Drive/ECSE 415/Assignment-3/'
img = cv2.imread(drive_path+'Schitts_Creek_group.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier(drive_path+'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(img_gray, 1.1, 2)
for (x,y,w,h) in faces:
    gray = cv2.rectangle(img_gray,(x,y),(x+w,y+h),(255,0,0),2)

plt.imshow(img_gray, cmap="gray")
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Viola Jones outperformed the detector I created. My program resulted in both false positives and missed faces, while Viola Jones avoided that due to it's more sophisticated training set and algorithm. The PCA is heavily dependent on the data set i feed it. Since the first 4 subjects in the dataset were male, it would make it more difficult for the PCA to detect female faces. The data set i gave could have had too little or too much variance. Viola Jones uses a different method of identifying faces, finding key portions of faces (eyes, nose, mouth) and finding where they allign to find the. This makes it easier detect faces like the second person from the left, who's head is tilted at an angle. None of my subjects had a similar profile in the training set, so it would have been difficult for my method to detect it.
#
# Vioal Jones: 4 true positives, 0 false positives, 0 false negatives
#
# Mine: 3 True positives, 4 false positives, 2 false negatives
